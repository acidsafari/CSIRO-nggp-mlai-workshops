# %%
import subprocess
import sys
from pathlib import Path

if "google.colab" in sys.modules:
    repo_dir = Path("/content/nextgen2026-mlai-workshops")
    if not repo_dir.exists():
        subprocess.run(
            [
                "git",
                "clone",
                "--depth",
                "1",
                "--branch",
                "workshop0-setup",
                "https://github.com/nextgenerationgraduatesprogram/nextgen2026-mlai-workshops.git",
                str(repo_dir),
            ],
            check=True,
        )
    sys.path.insert(0, str(repo_dir / "src"))

# %%
import nextgen2026_mlai_workshops as workshop

print(f"Workshop package version: {workshop.__version__}")
print(f"Package source: {workshop.__file__}")

# %%
print("hello world")
